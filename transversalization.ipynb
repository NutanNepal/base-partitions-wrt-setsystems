# %%
m = 3
M = matroids.Uniform(2, 3)
set_system = [{1,0}, {1,2,0}]
basis = list(M.bases())
basis
# Out:
# [frozenset({0, 1}), frozenset({0, 2}), frozenset({1, 2})]

# %%
P = PolynomialRing(QQ, 'x', m)
Q = PolynomialRing(QQ, 'y', len(set_system))
x = P.gens()
y = Q.gens()

# %%
bgp = sum(prod(x[i] for i in b) for b in basis)
bgp

def egp_setsystem(alpha):
    p = 0
# Out:
# x0*x1 + x0*x2 + x1*x2
