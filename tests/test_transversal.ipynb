# %%
import sys
import os

# Add parent directory to path to import lib
sys.path.append(os.path.dirname(os.path.abspath('')))

from lib.transversalization import *

# %%
print("Testing Transversalization Operator...")

S = [
    {1, 2},    # S_1
    {1, 2, 3}  # S_2
]

print(f"Set System S: {S}")
# Out:
# Testing Transversalization Operator...
# Set System S: [{1, 2}, {1, 2, 3}]

# %%
alpha1 = (2, 1, 0)
beta1 = (1, 2)

print(f"Checking if alpha={alpha1} admits S-transversal to beta={beta1}:")
result1 = check_admits_transversal(alpha1, beta1, S)
print(f"Result: {result1}")
# Out:
# Checking if alpha=(2, 1, 0) admits S-transversal to beta=(1, 2):
# Result: True
